# %% [markdown]
# # **Project Name**    -    *Ford Bike Sharing*

# %% [markdown]
# Project Type - Exaploratory Data Analysis
#
# Contribution - Individual
#
# Individual - Jada Vijay

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project explores Ford GoBike trip data for January 2018 to understand trip duration patterns.
# We analyzed how trip duration varies by user type and day of the week.
#
# #### Key Insights :
#
# - The average trip duration was around X minutes.
#
# - Customers generally had longer trips compared to Subscribers.
#
# - No seasonal effects could be assessed as the data covered only January.
#
# - Subscribers mostly used bikes for short, regular trips, while Customers often took longer rides.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# This project focuses on analyzing bike trip data from Ford GoBike to gain insights into trip durations.
#
# ####The main objectives are:
#
# - To find out the average time users spend on trips.
#
# - To explore if trip duration is influenced by seasons or time factors.
#
# - To examine differences in trip patterns between Subscribers and Customers.
#
# By identifying these patterns, the analysis aims to support business decisions that can enhance user experience, attract more customers, and improve subscription rates.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective of this analysis is to help Ford GoBike better understand user behavior based on trip duration and user type.
#
# By identifying patterns in how different users (Subscribers vs Customers) use the service, the company can:
#
# 1. Improve service offerings tailored to each user group.
#
# 2. Develop strategies to convert casual Customers into long-term Subscribers.
#
# 3. Optimize operations based on typical trip durations and peak usage times.
#
# 4. Increase overall customer satisfaction and maximize revenue growth.
#
# Ultimately, these insights aim to support Ford GoBike in making data-driven decisions that enhance service usage and market competitiveness.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Analysis begins from here***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df = pd.read_csv('/content/201801-fordgobike-tripdata.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df
# Out:
#        duration_sec                start_time                  end_time  \
# 0             75284  2018-01-31 22:52:35.2390  2018-02-01 19:47:19.8240
# 1             85422  2018-01-31 16:13:34.3510  2018-02-01 15:57:17.3100
# 2             71576  2018-01-31 14:23:55.8890  2018-02-01 10:16:52.1160
# 3             61076  2018-01-31 14:53:23.5620  2018-02-01 07:51:20.5000
# 4             39966  2018-01-31 19:52:24.6670  2018-02-01 06:58:31.0530
# ...             ...                       ...                       ...
# 94797           695  2018-01-01 00:19:58.7610  2018-01-01 00:31:33.8320
# 94798           600  2018-01-01 00:19:48.7610  2018-01-01 00:29:49.0740
# 94799          1151  2018-01-01 00:09:31.7450  2018-01-01 00:28:43.1590
# 94800           714  2018-01-01 00:07:52.9430  2018-01-01 00:19:47.0750
# 94801           145  2018-01-01 00:07:41.0400  2018-01-01 00:10:06.2410
#
#        start_station_id                                 start_station_name  \
# ...

# %%
#Top 5 Instances
df.head()   #head function will give you the top 5 rows from the dataset
# Out:
#    duration_sec                start_time                  end_time  \
# 0         75284  2018-01-31 22:52:35.2390  2018-02-01 19:47:19.8240
# 1         85422  2018-01-31 16:13:34.3510  2018-02-01 15:57:17.3100
# 2         71576  2018-01-31 14:23:55.8890  2018-02-01 10:16:52.1160
# 3         61076  2018-01-31 14:53:23.5620  2018-02-01 07:51:20.5000
# 4         39966  2018-01-31 19:52:24.6670  2018-02-01 06:58:31.0530
#
#    start_station_id                                 start_station_name  \
# 0               120                               Mission Dolores Park
# 1                15  San Francisco Ferry Building (Harry Bridges Pl...
# 2               304                               Jackson St at 5th St
# 3                75                           Market St at Franklin St
# 4                74                              Laguna St at Hayes St
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# ...

# %%
#Bottom 5 Instances
df.tail()     #tail function gives you the bottom 5 rows from the dataset
# Out:
#        duration_sec                start_time                  end_time  \
# 94797           695  2018-01-01 00:19:58.7610  2018-01-01 00:31:33.8320
# 94798           600  2018-01-01 00:19:48.7610  2018-01-01 00:29:49.0740
# 94799          1151  2018-01-01 00:09:31.7450  2018-01-01 00:28:43.1590
# 94800           714  2018-01-01 00:07:52.9430  2018-01-01 00:19:47.0750
# 94801           145  2018-01-01 00:07:41.0400  2018-01-01 00:10:06.2410
#
#        start_station_id                                start_station_name  \
# 94797                23                     The Embarcadero at Steuart St
# 94798                17  Embarcadero BART Station (Beale St at Market St)
# 94799                97                             14th St at Mission St
# 94800                74                             Laguna St at Hayes St
# 94801               316                         San Salvador St at 1st St
#
#        start_station_latitude  start_station_longitude  end_station_id  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (94802, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94802 entries, 0 to 94801
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   duration_sec             94802 non-null  int64
#  1   start_time               94802 non-null  object
#  2   end_time                 94802 non-null  object
#  3   start_station_id         94802 non-null  int64
#  4   start_station_name       94802 non-null  object
#  5   start_station_latitude   94802 non-null  float64
#  6   start_station_longitude  94802 non-null  float64
#  7   end_station_id           94802 non-null  int64
#  8   end_station_name         94802 non-null  object
#  9   end_station_latitude     94802 non-null  float64
#  10  end_station_longitude    94802 non-null  float64
#  11  bike_id                  94802 non-null  int64
#  12  user_type                94802 non-null  object
#  13  member_birth_year        86963 non-null  float64
# ...

# %%
#Data type of each column
df.dtypes
# Out:
# duration_sec                 int64
# start_time                  object
# end_time                    object
# start_station_id             int64
# start_station_name          object
# start_station_latitude     float64
# start_station_longitude    float64
# end_station_id               int64
# end_station_name            object
# end_station_latitude       float64
# end_station_longitude      float64
# bike_id                      int64
# user_type                   object
# member_birth_year          float64
# member_gender               object
# bike_share_for_all_trip     object
# dtype: object

# %%
print(df.dtypes)     #for different action, the output will vary, used with print and without print as well.
# Out:
# duration_sec                 int64
# start_time                  object
# end_time                    object
# start_station_id             int64
# start_station_name          object
# start_station_latitude     float64
# start_station_longitude    float64
# end_station_id               int64
# end_station_name            object
# end_station_latitude       float64
# end_station_longitude      float64
# bike_id                      int64
# user_type                   object
# member_birth_year          float64
# member_gender               object
# bike_share_for_all_trip     object
# dtype: object

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 94797    False
# 94798    False
# 94799    False
# 94800    False
# 94801    False
# Length: 94802, dtype: bool

# %%
#Gives the count of duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values
df.isnull()
# Out:
#        duration_sec  start_time  end_time  start_station_id  \
# 0             False       False     False             False
# 1             False       False     False             False
# 2             False       False     False             False
# 3             False       False     False             False
# 4             False       False     False             False
# ...             ...         ...       ...               ...
# 94797         False       False     False             False
# 94798         False       False     False             False
# 94799         False       False     False             False
# 94800         False       False     False             False
# 94801         False       False     False             False
#
#        start_station_name  start_station_latitude  start_station_longitude  \
# 0                   False                   False                    False
# 1                   False                   False                    False
# ...

# %%
#Null values count
df.isnull().sum()
# Out:
# duration_sec                  0
# start_time                    0
# end_time                      0
# start_station_id              0
# start_station_name            0
# start_station_latitude        0
# start_station_longitude       0
# end_station_id                0
# end_station_name              0
# end_station_latitude          0
# end_station_longitude         0
# bike_id                       0
# user_type                     0
# member_birth_year          7839
# member_gender              7801
# bike_share_for_all_trip       0
# dtype: int64

# %%
# Visualizing the missing values
# Create a heatmap of missing values
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %%
#Count of missing values
missing_values = df.isnull().sum()
missing_values = missing_values[missing_values > 0]
plt.figure(figsize=(10,6))
missing_values.plot(kind='bar', color='skyblue')
plt.title('Number of Missing Values per Column')
plt.xlabel('Columns')
plt.ylabel('Number of Missing Values')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# These columns are generally part of trip-based data from bike-sharing systems like Ford GoBike.
#
# 1. Trip Duration: The length of time the bike was used.
#
# 2. Start Time / End Time: Timestamps for when the bike trip started and ended.
#
# 3. Start Station / End Station: The locations where the bike trip started and ended.
#
# 4. User Type: Usually categorizes users into types such as "Subscriber" or "Customer."
#
# 5. Bike ID: Unique identifier for each bike used in the sharing system.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['duration_sec', 'start_time', 'end_time', 'start_station_id',
#        'start_station_name', 'start_station_latitude',
#        'start_station_longitude', 'end_station_id', 'end_station_name',
#        'end_station_latitude', 'end_station_longitude', 'bike_id', 'user_type',
#        'member_birth_year', 'member_gender', 'bike_share_for_all_trip'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#        duration_sec  start_station_id  start_station_latitude  \
# count  94802.000000      94802.000000            94802.000000
# mean     870.935930        103.766302               37.773321
# std     2550.596891         87.730464                0.085744
# min       61.000000          3.000000               37.317298
# 25%      359.000000         30.000000               37.771662
# 50%      555.000000         79.000000               37.781270
# 75%      854.000000        160.000000               37.795392
# max    85546.000000        342.000000               37.880222
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count             94802.000000     94802.00000          94802.000000
# mean               -122.361677       101.00982             37.773536
# std                   0.105253        86.77949              0.085552
# min                -122.444293         3.00000             37.317298
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# | **Variable**         | **Description**                                                       |
# |----------------------|-----------------------------------------------------------------------|
# | **Trip Duration**     | Total trip time in seconds                                            |
# | **Start Time**        | Timestamp of when the trip started                                    |
# | **End Time**          | Timestamp of when the trip ended                                      |
# | **Start Station**     | Name of the start station                                             |
# | **End Station**       | Name of the end station                                               |
# | **User Type**         | Subscriber or Customer type                                           |
# | **Bike ID**           | Unique bike identifier                                                |
# | **Gender**            | Gender of the user (0=Unknown, 1=Male, 2=Female)                      |
# | **Birth Year**        | Birth year of the user                                                |
# | **Age**               | Age of the user (calculated from birth year)                          |
# | **Start Latitude**    | Latitude of the start station                                         |
# |

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
# Create a DataFrame with unique values for each column
unique_values = {column: df[column].unique() for column in df.columns}
unique_df = pd.DataFrame(list(unique_values.items()), columns=['Variable', 'Unique Values'])

# Display the DataFrame
unique_df
# Out:
#                    Variable                                      Unique Values
# 0              duration_sec  [75284, 85422, 71576, 61076, 39966, 6477, 453,...
# 1                start_time  [2018-01-31 22:52:35.2390, 2018-01-31 16:13:34...
# 2                  end_time  [2018-02-01 19:47:19.8240, 2018-02-01 15:57:17...
# 3          start_station_id  [120, 15, 304, 75, 74, 236, 110, 81, 134, 305,...
# 4        start_station_name  [Mission Dolores Park, San Francisco Ferry Bui...
# 5    start_station_latitude  [37.7614205, 37.795392, 37.3487586867448, 37.7...
# 6   start_station_longitude  [-122.4264353, -122.394203, -121.8947978317737...
# 7            end_station_id  [285, 15, 296, 47, 19, 160, 134, 93, 4, 317, 4...
# 8          end_station_name  [Webster St at O'Farrell St, San Francisco Fer...
# 9      end_station_latitude  [37.78352083526095, 37.795392, 37.3259984, 37....
# 10    end_station_longitude  [-122.43115782737732, -122.394203, -121.87712,...
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Impute missing values with median (example for a column 'duration_sec')
df['duration_sec'].fillna(df['duration_sec'].median(), inplace=True)

# 2. Converting Data Types
# Convert 'start_time' to datetime and 'user_type' to categorical
df['start_time'] = pd.to_datetime(df['start_time'])
df['user_type'] = df['user_type'].astype('category')

# 3. Handling Outliers
# Remove trips with duration greater than 10,000 seconds
df = df[df['duration_sec'] < 10000]

# 4. Filtering Data
# Filter data for 'Subscribers' only
df_subscribers = df[df['user_type'] == 'Subscriber']

# **Instead of filtering for an entire year (2018), filter for January 2018 as your data suggests:**
df = df[(df['start_time'] >= '2018-01-01') & (df['start_time'] <= '2018-01-31')]

# If you still get the error, comment out ALL filtering and identify which filter is causing the issue:

# df = df[df['duration_sec'] < 10000]  # comment to test
# df_subscribers = df[df['user_type'] == 'Subscriber']  # comment to test
# df = df[(df['start_time'] >= '2018-01-01') & (df['start_time'] <= '2018-01-31')]  # comment to test


# 5. Creating New Columns
# Extract hour from 'start_time' and day of the week
df['hour'] = df['start_time'].dt.hour
df['day_of_week'] = df['start_time'].dt.dayofweek

# Calculate age from birth year
current_year = 2025
# Check if 'member_birth_year' column exists in your DataFrame, if not use the name of the correct column
if 'member_birth_year' in df.columns:
    df['age'] = current_year - df['member_birth_year']
elif 'birth_year' in df.columns:
    df['age'] = current_year - df['birth_year']
else:
    print("Column for birth year not found.")

# 6. Removing Duplicates
df.drop_duplicates(inplace=True)

# 7. Renaming Columns
df.rename(columns={'start_station_name': 'Start Station', 'end_station_name': 'End Station'}, inplace=True)

# Before using MinMaxScaler, install and import it
# !pip install scikit-learn
from sklearn.preprocessing import MinMaxScaler

# 8. Normalizing or Scaling Data (Example: Normalizing 'duration_sec')
# Check if df is empty before scaling
if df.empty:
    print("DataFrame is empty after filtering. Check your filters.")
else:
    scaler = MinMaxScaler()
    df['normalized_duration'] = scaler.fit_transform(df[['duration_sec']])

# 9. Categorizing Data (Example: Categorizing 'age' into age groups)
bins = [0, 18, 35, 60, 100]
labels = ['<18', '18-35', '35-60', '60+']
df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels)

# Display the first few rows of the cleaned dataset
df.head()
# Out:
# <ipython-input-21-9a1d1a27098b>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['duration_sec'].fillna(df['duration_sec'].median(), inplace=True)
# ...
#       duration_sec              start_time                  end_time  \
# 4484           407 2018-01-30 23:58:50.242  2018-01-31 00:05:38.1340
# 4485           161 2018-01-30 23:57:17.156  2018-01-30 23:59:58.7720
# 4486           581 2018-01-30 23:47:19.273  2018-01-30 23:57:00.3450
# 4487          1234 2018-01-30 23:33:05.070  2018-01-30 23:53:39.6200
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# ### Manipulations :
#
# 1. Imputed missing values in duration_sec using the median.
#
# 2. Data Type Conversion: Converted start_time to datetime and user_type to categorical.
#
# 3. Outlier Handling: Removed trips with durations > 10,000 seconds.
#
# 4. Data Filtering: Filtered data for "Subscribers" and trips in 2021.
#
# 5. New Columns: Added hour, day_of_week, and age from birth_year.
#
# 6. Duplicate Removal: Removed duplicate rows.
#
# 7. Column Renaming: Renamed station columns for clarity.
#
# 8. Normalization: Scaled duration_sec using Min-Max normalization.
#
# 9. Categorization: Categorized age into groups (<18, 18-35, 35-60, 60+).
#
# ### Insights :
#
# 1. Trip Duration: Outlier removal helps analyze typical trip durations.
#
# 2. User Demographics: Age groups and user types (Subscriber vs. Customer) can reveal trends in usage.
#
# 3. Time Trends: Hour and day analysis helps identify peak usage times.
#
# 4. Station Usage: Renamed columns allow easy analysis of start and end station usage.
#
# 5. Geography: Lat/long data can help analyze trip routes and station popularity.
#
# 6. Data Quality: Removing duplicates ensures clean, accurate data for analysis.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Line plot for average trip duration by hour

# Convert 'start_time' to datetime objects
df['start_time'] = pd.to_datetime(df['start_time'])

# Extract the hour from the 'start_time' column
df['hour'] = df['start_time'].dt.hour

avg_duration_by_hour = df.groupby('hour')['duration_sec'].mean()
avg_duration_by_hour.plot(kind='line', marker='o', color='blue')
plt.title('Average Trip Duration by Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Average Duration (seconds)')
plt.xticks(range(0, 24))
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line plot is useful for showing trends over time. In this case, it illustrates how the average trip duration varies by the hour of the day, making it easy to spot patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart can reveal peak hours for longer trips, indicating when users tend to take more leisurely rides versus short trips. It also highlights less busy hours where bike availability can be increased.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this can help optimize bike availability during peak hours and adjust pricing models or promotions based on when people tend to take longer trips. It can also guide staff allocation during busy times.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
#Histogram
import matplotlib.pyplot as plt

# Plot histogram for trip durations
plt.hist(df['duration_sec'], bins=30, color='red', edgecolor='black')
plt.title('Distribution of Trip Durations')
plt.xlabel('Duration (seconds)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is perfect for visualizing the distribution of a numerical variable, like duration_sec. It helps to see the frequency of various trip durations and identify any skewness in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram helps identify the most common trip durations. If there’s a peak around a specific range (e.g., short trips), it could indicate the type of users or trips that dominate, such as daily commuters.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding the distribution of trip durations can help the business optimize pricing strategies, marketing campaigns, and identify peak usage periods, which can improve customer experience and increase revenue.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Pie chart for gender distribution
# Check if 'member_gender' exists, if not, assume it's 'gender'
gender_column = 'member_gender' if 'member_gender' in df.columns else 'gender'

# Check if the gender column exists before plotting
if gender_column in df.columns:
    df[gender_column].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['orange', 'lightpink'])
    plt.title('Gender Distribution')
    plt.ylabel('')
    plt.show()
else:
    print(f"Column '{gender_column}' not found in DataFrame. Check column names.")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is great for showing the proportion of different categories, and it's perfect for visualizing the distribution of users by gender in this case.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart can reveal if one gender is overrepresented in bike usage. If a significant skew exists, the company may consider gender-targeted marketing or promotions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, gender-based insights can drive more targeted marketing campaigns. If one gender is underrepresented, the business can tailor advertising strategies to attract that group, ultimately increasing usage and customer engagement.

# %% [markdown]
# #### Chart - 4

# %%
#Chart - 4 visualization code
# Count plot for trips by day of the week
sns.countplot(x='day_of_week', data=df, palette='Set1')
plt.title('Number of Trips by Day of the Week')
plt.xlabel('Day of Week')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-44-3a7386bb52f5>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='day_of_week', data=df, palette='Set1')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot is excellent for visualizing categorical data over different categories (e.g., days of the week). It helps identify patterns like peak usage days.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart will likely show that weekends have higher trip counts than weekdays, or vice versa, depending on user behavior. It could also highlight which days are the least busy.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding the busiest days allows the business to optimize bike distribution, staffing, and promotions on less busy days to increase customer activity, improving overall efficiency and sales.

# %% [markdown]
# #### Chart - 5

# %%
# Scatter plot for duration vs age
plt.scatter(df['age'], df['duration_sec'], alpha=0.5, color='indigo')
plt.title('Trip Duration vs Age')
plt.xlabel('Age')
plt.ylabel('Trip Duration (seconds)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is ideal for visualizing the relationship between two numerical variables. It can show if there is any trend or pattern between user age and trip duration.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot might reveal that younger users tend to take shorter trips while older users might take longer trips, or it could show no correlation at all.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights could inform customer profiling, allowing the business to target specific age groups with tailored promotions or offers that match their trip habits, thus improving engagement.

# %% [markdown]
# #### Chart - 6 - Correlation Heatmap

# %%
#Chart - 5 visualization code
# Heatmap for correlation matrix
corr = df[['duration_sec', 'age', 'hour']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap is excellent for visualizing the relationships between multiple variables, especially correlations. It allows for a quick understanding of which numerical features are related to each other.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap can reveal correlations between trip duration and other features like age or hour. For example, it may show that older users tend to take shorter trips or that trips during certain hours are longer.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding correlations can help the business tailor its services. If certain age groups tend to take shorter trips, the company can create tailored offers or adjust bike placement to match user behavior, enhancing satisfaction and efficiency.

# %% [markdown]
# #### Chart - 7 - Pair Plot

# %%
# Chart - 6 visualization code
# Pair plot for numerical columns
sns.pairplot(df[['duration_sec', 'age', 'hour']])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is ideal for visualizing relationships across multiple variables. It allows for comparisons between duration_sec, age, and hour, showing how these factors interact.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot can reveal any interesting correlations between the variables, such as whether longer trips occur during certain hours or with specific age groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help the business optimize bike allocation and services. For instance, if younger users tend to use bikes more during the evening, targeted promotions could be run to maximize usage during those times.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To achieve the business objectives, I suggest focusing on increasing subscription users, optimizing bike availability based on peak demand times, and expanding the customer base by targeting underrepresented groups like females and older users.
# Marketing efforts should highlight the benefits of short-trip plans and promote special offers during weekends and off-peak hours.
# Additionally, continuous monitoring of trip patterns and user behavior will help in improving service quality and customer satisfaction, leading to long-term business growth.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The Ford Bike Sharing trip data analysis revealed that short trips dominate user behavior, with subscribers contributing the most rides compared to casual customers.
# Trip durations vary slightly based on time of day, age, and gender, but most users prefer quick, convenient rides, mainly during weekdays.
# Business strategies focused on subscription growth, time-specific promotions, and diverse user engagement will help improve service efficiency and boost revenue.
