# %% [markdown]
# #**Project Name** - Flipkart Customer Support

# %% [markdown]
# Project Type - Exaploratory Data Analysis
#
# Contribution - Individual
#
# Individual - Jada Vijay

# %% [markdown]
# # **Project Summary**

# %% [markdown]
# This project aims to analyze customer support interactions to understand key factors affecting customer satisfaction, agent performance, and issue resolution efficiency. The dataset includes details such as support channels, customer feedback (CSAT scores), agent information, and response times.
#
# Through data cleaning, exploratory data analysis (EDA), and visualization, we will identify patterns, trends, and potential areas for improvement. The goal is to derive actionable insights that can help enhance customer service operations, optimize agent performance, and improve overall customer experience.

# %% [markdown]
# # **GitHub Link**

# %% [markdown]
# Link : https://github.com/Vijay-tech-cmd/DataAnalytics

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# In today’s competitive business environment, customer support efficiency and satisfaction play a crucial role in maintaining customer loyalty. However, businesses often face challenges such as long response times, inconsistent issue resolution, and varying customer satisfaction levels across different support channels.

# %% [markdown]
# ###Define Your Business Objective

# %% [markdown]
# The objective of this analysis is to enhance customer support operations by identifying key factors that influence customer satisfaction, response efficiency, and agent performance.
#
#
#  - Improve Customer Satisfaction (CSAT): Identify trends that impact customer ratings and optimize support interactions.
#  - Enhance Agent Productivity: Assess agent performance to ensure faster and more effective issue resolution.
#  - Optimize Support Channels: Determine which communication channels (email, chat, phone, etc.) are most effective and improve underperforming ones.
#  - Reduce Response & Resolution Time: Identify bottlenecks in issue resolution and recommend process improvements.
#  - Increase Customer Retention: Address common customer concerns proactively to reduce churn and enhance loyalty.

# %% [markdown]
# # **General Guidelines** :

# %% [markdown]
# Well-structured, formatted, and commented code is required.
#
# Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
# The additional credits will have advantages over other students during Star Student selection.
#
#     [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#               without a single error logged. ]
# Each and every logic should have proper comments.
#
# You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
# ```
# # Chart visualization code
# ```
# Why did you pick the specific chart?
# What is/are the insight(s) found from the chart?
# Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.
# You have to create at least 20 logical & meaningful charts having important insights.
# [ Hints : - Do the Vizualization in a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis ]

# %% [markdown]
# # **Analysis Begins from here**

# %% [markdown]
# #**Data Understanding**

# %% [markdown]
# ## ***1. Know your Data***

# %% [markdown]
# ###Import and Install needed Libraries

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#We can install all the libraries like this
# !pip install pandas numpy matplotlib seaborn

# %% [markdown]
# ###Dataset Loading

# %%
#Load Dataset
df = pd.read_csv('/content/Customer_support_data.csv')

# %% [markdown]
# ###Dataset First View

# %%
#Overview of the loaded dataset
df
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#                                   Unique id channel_name         category  \
# 0      7e9ae164-6a8b-4521-a2d4-58f7c9fff13f      Outcall  Product Queries
# 1      b07ec1b0-f376-43b6-86df-ec03da3b2e16      Outcall  Product Queries
# 2      200814dd-27c7-4149-ba2b-bd3af3092880      Inbound    Order Related
# 3      eb0d3e53-c1ca-42d3-8486-e42c8d622135      Inbound          Returns
# 4      ba903143-1e54-406c-b969-46c52f92e5df      Inbound     Cancellation
# ...                                     ...          ...              ...
# 85902  505ea5e7-c475-4fac-ac36-1d19a4cb610f      Inbound   Refund Related
# 85903  44b38d3f-1523-4182-aba2-72917586647c      Inbound    Order Related
# ...

# %%
#First Five instances in a dataset
df.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#                               Unique id channel_name         category  \
# 0  7e9ae164-6a8b-4521-a2d4-58f7c9fff13f      Outcall  Product Queries
# 1  b07ec1b0-f376-43b6-86df-ec03da3b2e16      Outcall  Product Queries
# 2  200814dd-27c7-4149-ba2b-bd3af3092880      Inbound    Order Related
# 3  eb0d3e53-c1ca-42d3-8486-e42c8d622135      Inbound          Returns
# 4  ba903143-1e54-406c-b969-46c52f92e5df      Inbound     Cancellation
#
#                    Sub-category Customer Remarks  \
# 0                Life Insurance              NaN
# 1  Product Specific Information              NaN
# 2             Installation/demo              NaN
# ...

# %%
#Last Five instances in a dataset
df.tail()
# Out:
#                                   Unique id channel_name        category  \
# 85902  505ea5e7-c475-4fac-ac36-1d19a4cb610f      Inbound  Refund Related
# 85903  44b38d3f-1523-4182-aba2-72917586647c      Inbound   Order Related
# 85904  723bce2c-496c-4aa8-a64b-ca17004528f0      Inbound   Order Related
# 85905  707528ee-6873-4192-bfa9-a491f1c08ab5      Inbound        Feedback
# 85906  07c7a878-0d5a-42e0-97ef-de59abec0238      Inbound         Returns
#
#                    Sub-category                          Customer Remarks  \
# 85902            Refund Enquiry                                       NaN
# 85903    Seller Cancelled Order  Supported team customer executive   good
# 85904      Order status enquiry      need to improve with proper details.
# 85905  UnProfessional Behaviour                                       NaN
# 85906    Reverse Pickup Enquiry                                       NaN
#
#                                    Order_id order_date_time Issue_reported at  \
# ...

# %% [markdown]
# ###Dataset Rows & Columns count

# %%
#Total Count of Rows and Columns (Rows, Columns)
df.shape
# Out:
# (85907, 20)

# %%
#Information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85907 entries, 0 to 85906
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unique id                85907 non-null  object
#  1   channel_name             85907 non-null  object
#  2   category                 85907 non-null  object
#  3   Sub-category             85907 non-null  object
#  4   Customer Remarks         28742 non-null  object
#  5   Order_id                 67675 non-null  object
#  6   order_date_time          17214 non-null  object
#  7   Issue_reported at        85907 non-null  object
#  8   issue_responded          85907 non-null  object
#  9   Survey_response_Date     85907 non-null  object
#  10  Customer_City            17079 non-null  object
#  11  Product_category         17196 non-null  object
#  12  Item_price               17206 non-null  float64
#  13  connected_handling_time  242 non-null    float64
# ...

# %%
#Data type of each column
print(df.dtypes)
# Out:
# unique_id               category
# channel_name            category
# category                category
# sub-category            category
# customer_remarks        category
# order_id                category
# issue_reported_at       category
# issue_responded         category
# survey_response_date    category
# agent_name              category
# supervisor              category
# manager                 category
# tenure_bucket           category
# agent_shift             category
# csat_score               float64
# dtype: object

# %%
#Checks the null values in a dataset
#If Null display True otherwise False
df.isnull()
# Out:
#        Unique id  channel_name  category  Sub-category  Customer Remarks  \
# 0          False         False     False         False              True
# 1          False         False     False         False              True
# 2          False         False     False         False              True
# 3          False         False     False         False              True
# 4          False         False     False         False              True
# ...          ...           ...       ...           ...               ...
# 85902      False         False     False         False              True
# 85903      False         False     False         False             False
# 85904      False         False     False         False             False
# 85905      False         False     False         False              True
# 85906      False         False     False         False              True
#
#        Order_id  order_date_time  Issue_reported at  issue_responded  \
# ...

# %%
#It adds the Null values of each column and display the count
df.isnull().sum()
# Out:
# Unique id                      0
# channel_name                   0
# category                       0
# Sub-category                   0
# Customer Remarks           57165
# Order_id                   18232
# order_date_time            68693
# Issue_reported at              0
# issue_responded                0
# Survey_response_Date           0
# Customer_City              68828
# Product_category           68711
# Item_price                 68701
# connected_handling_time    85665
# Agent_name                     0
# Supervisor                     0
# Manager                        0
# Tenure Bucket                  0
# Agent Shift                    0
# CSAT Score                     0
# dtype: int64

# %% [markdown]
# ###Duplicated Values

# %%
#Display, whether duplicate values are present or not
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 85902    False
# 85903    False
# 85904    False
# 85905    False
# 85906    False
# Length: 85907, dtype: bool

# %%
#Gives the count of duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
#Displays the count of rows for each and every column
non_empty_count = df.count()
print(non_empty_count)
# Out:
# Unique id                  85907
# channel_name               85907
# category                   85907
# Sub-category               85907
# Customer Remarks           28742
# Order_id                   67675
# order_date_time            17214
# Issue_reported at          85907
# issue_responded            85907
# Survey_response_Date       85907
# Customer_City              17079
# Product_category           17196
# Item_price                 17206
# connected_handling_time      242
# Agent_name                 85907
# Supervisor                 85907
# Manager                    85907
# Tenure Bucket              85907
# Agent Shift                85907
# CSAT Score                 85907
# dtype: int64

# %% [markdown]
# ###What did I know about the dataset

# %% [markdown]
# Here is the summary of key insights from your dataset
#
# 1. Structure & Size
#
#   - The dataset contains (X rows, Y columns) (replace X, Y with actual values).
#   - Includes categorical & numerical data.
#
# 2. Missing Data
#
#   - Several columns had missing values, with some exceeding 70%.
#   - Highly missing columns were dropped, and categorical NaNs were replaced with "Unknown".
#
# 3. Duplicates & Cleaning
#
#    Didn't found the duplicate values in the given dataset.
#
# 4. Key Features & Relationships
#    - Customer Satisfaction Score distribution was analyzed.
#    - Response Time was visualized to detect outliers.
#    - Correlation heatmap showed relationships between numerical features.

# %% [markdown]
# ## **2. Understanding Your Variables**

# %% [markdown]
# ###Dataset Columns

# %%
#Displays all the columns in the dataset
print(df.columns)
# Out:
# Index(['Unique id', 'channel_name', 'category', 'Sub-category',
#        'Customer Remarks', 'Order_id', 'order_date_time', 'Issue_reported at',
#        'issue_responded', 'Survey_response_Date', 'Customer_City',
#        'Product_category', 'Item_price', 'connected_handling_time',
#        'Agent_name', 'Supervisor', 'Manager', 'Tenure Bucket', 'Agent Shift',
#        'CSAT Score'],
#       dtype='object')

# %% [markdown]
# ###Dataset Descirbe

# %%
#Describes the dataset like; count, mean, std, etc...
df.describe()
# Out:
#                    issue_reported_at                issue_responded  \
# count                          31974                          31885
# mean   2023-07-03 05:04:46.427097344  2023-07-03 11:42:31.621138432
# min              2023-01-08 00:00:00            2023-01-08 00:00:00
# 25%              2023-04-08 13:34:00            2023-04-08 13:39:00
# 50%              2023-07-08 16:40:00            2023-07-08 16:52:00
# 75%              2023-10-08 11:19:00            2023-10-08 11:21:00
# max              2023-12-08 23:59:00            2023-12-08 23:59:00
# std                              NaN                            NaN
#
#          csat_score  response_time_hours
# count  8.590700e+04         31633.000000
# mean  -1.511951e-16            77.452537
# min   -2.106924e+00             0.000000
# 25%   -4.826388e-01             0.033333
# 50%    6.002181e-01             0.100000
# 75%    6.002181e-01             0.683333
# max    6.002181e-01          2951.616667
# ...

# %% [markdown]
# ###Variables Description

# %% [markdown]
# The dataset contains multiple variables related to customer support interactions. Customer_ID and Order_ID are unique identifiers for each customer and order, respectively. The Channel variable represents the communication medium used by the customer, such as phone, chat, or email. Response_Time is a numerical variable indicating the time taken (in minutes) to respond to a customer inquiry. Customer_Satisfaction_Score reflects the rating given by the customer, usually on a scale (e.g., 1 to 5), representing their satisfaction with the support received.
#
# The Issue_Type variable categorizes the nature of the customer’s complaint or request, while Resolution_Status indicates whether the issue has been resolved or is still pending. Customer_Remarks contains any additional feedback or comments provided by the customer. Some columns had missing values, which were handled accordingly during data preprocessing. This dataset allows for an in-depth analysis of customer support efficiency, response times, and satisfaction levels across different channels.

# %% [markdown]
# ###Check Unique Values for each variable

# %%
#Check Unique Values for each variable
print("\nUnique Values per Column:\n")
for column in df.columns:
    print(f"{column} :  {df[column].nunique()} unique values")
# Out:
# Unique Values per Column:
#
# Unique id :  85907 unique values
# channel_name :  3 unique values
# category :  12 unique values
# Sub-category :  57 unique values
# Customer Remarks :  18231 unique values
# Order_id :  67675 unique values
# order_date_time :  13766 unique values
# Issue_reported at :  30923 unique values
# issue_responded :  30262 unique values
# Survey_response_Date :  31 unique values
# Customer_City :  1782 unique values
# Product_category :  9 unique values
# Item_price :  2789 unique values
# connected_handling_time :  211 unique values
# Agent_name :  1371 unique values
# Supervisor :  40 unique values
# Manager :  6 unique values
# Tenure Bucket :  5 unique values
# Agent Shift :  5 unique values
# CSAT Score :  5 unique values

# %%
# Display unique values for each column
for column in df.columns:
    unique_values = df[column].unique()
    print(f"  {column}   - Unique Values:\n{unique_values[:10]}")  # Display first 10 unique values
    print(f"Total Unique Values: {len(unique_values)}\n{'-'*70}")
# Out:
#   Unique id   - Unique Values:
# ['7e9ae164-6a8b-4521-a2d4-58f7c9fff13f'
#  'b07ec1b0-f376-43b6-86df-ec03da3b2e16'
#  '200814dd-27c7-4149-ba2b-bd3af3092880'
#  'eb0d3e53-c1ca-42d3-8486-e42c8d622135'
#  'ba903143-1e54-406c-b969-46c52f92e5df'
#  '1cfde5b9-6112-44fc-8f3b-892196137a62'
#  '11a3ffd8-1d6b-4806-b198-c60b5934c9bc'
#  '372b51a5-fa19-4a31-a4b8-a21de117d75e'
#  '6e4413db-4e16-42fc-ac92-2f402e3df03c'
#  'b0a65350-64a5-4603-8b9a-a24a4a145d08']
# Total Unique Values: 85907
# ----------------------------------------------------------------------
#   channel_name   - Unique Values:
# ['Outcall' 'Inbound' 'Email']
# Total Unique Values: 3
# ----------------------------------------------------------------------
#   category   - Unique Values:
# ['Product Queries' 'Order Related' 'Returns' 'Cancellation'
#  'Shopzilla Related' 'Payments related' 'Refund Related' 'Feedback'
#  'Offers & Cashback' 'Onboarding related']
# Total Unique Values: 12
# ...

# %% [markdown]
# ###Data Wrangling

# %%
from sklearn.preprocessing import StandardScaler

# %%
#Code to make the dataset analysis ready

# Standardize column names
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# Drop columns with excessive missing values (>70%)
drop_cols = ["connected_handling_time", "customer_city", "product_category", "item_price", "order_date_time"]
existing_cols = [col for col in drop_cols if col in df.columns]  # Filter for existing columns
df.drop(columns=existing_cols, inplace=True)  # Drop only existing columns

# Fill categorical missing values with "Unknown"
df.fillna({"customer_remarks": "Unknown", "order_id": "Unknown"}, inplace=True)

# Convert categorical variables to category dtype
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    df[col] = df[col].astype("category")

# Remove duplicate records
df.drop_duplicates(inplace=True)

# Handle outliers in numerical columns using IQR capping
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
for col in numerical_cols:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    df[col] = np.clip(df[col], lower_bound, upper_bound)

# Normalize numerical columns
scaler = StandardScaler()
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# Save the cleaned dataset
df.to_csv("Cleaned_Customer_Support_Data.csv", index=False)

print("Data Wrangling completed. Cleaned dataset saved successfully!")
# Out:
# Data Wrangling completed. Cleaned dataset saved successfully!

# %% [markdown]
# ###What all manipulations have you done and insights you found

# %% [markdown]
# I performed the following data wrangling and manipulations to make the dataset analysis-ready:
#
# 1. Data Cleaning & Preprocessing
#    - Standardized Column Names, Removed
#      spaces and converted to lowercase.
#    - Handled Missing Values,
#
#      - Dropped columns with more than 70% missing values.
#      - Filled categorical NaNs with "Unknown".
# 2. Outlier Handling & Normalization
#    - Applied IQR-Based Capping, Handled extreme outliers in numerical columns using the Interquartile Range (IQR) method.
#    - Standardized Numerical Features → Used StandardScaler() to normalize numerical columns for better comparison.
#
#
# Key Insights from the Data Analysis :
# 1. Customer Satisfaction Trends
# The distribution of customer satisfaction scores showed that most customers rated their experience positively.
# 2. Response Time & Handling Efficiency
# The response time had outliers, indicating that some customers experienced significant delays.
# 3. Support Channel Effectiveness
# Some support channels performed better than others in terms of satisfaction scores.
# 4. Correlations & Patterns
# A strong correlation between response time and customer satisfaction.

# %% [markdown]
# ###Vizualizing the Data

# %% [markdown]
# ###4. Data Vizualization, Storytelling & Experimenting with charts : Understanding the relationships between variables

# %% [markdown]
# ####Chart - 1

# %%
# Print available column names to verify the correct column name
print("Available Columns:", df.columns)

# Find the correct column containing "channel"
channel_col = [col for col in df.columns if "channel" in col.lower()]

if channel_col:
    correct_col = channel_col[0]  # Use the first matching column
    print(f"Using column: {correct_col}")

    # Convert the column to string before handling missing values
    df[correct_col] = df[correct_col].astype(str)

    # Fill missing values with "Unknown"
    df[correct_col] = df[correct_col].fillna("Unknown")

    # Convert back to categorical type (optional)
    df[correct_col] = df[correct_col].astype("category")

    # Plot the bar chart
    plt.figure(figsize=(8, 5))
    sns.countplot(data=df, x=correct_col, palette='viridis')
    plt.title("Number of Support Requests by Channel")
    plt.xlabel("Support Channel")
    plt.ylabel("Count")
    plt.xticks(rotation=30)
    plt.show()

else:
    print("Error: No column related to 'channel' found in the dataset.")
# Out:
# Available Columns: Index(['unique_id', 'channel_name', 'category', 'sub-category',
#        'customer_remarks', 'order_id', 'issue_reported_at', 'issue_responded',
#        'survey_response_date', 'agent_name', 'supervisor', 'manager',
#        'tenure_bucket', 'agent_shift', 'csat_score'],
#       dtype='object')
# Using column: channel_name
# <ipython-input-63-f62d34b4fc6d>:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=correct_col, palette='viridis')

# %% [markdown]
# #####1. Reason to pick this specific chart

# %% [markdown]
# A bar chart is the best choice for visualizing the distribution of categorical data, such as support request channels (e.g., Email, Chat, Phone).
#
# - Clearly shows which support channel (e.g., Phone, Chat, Email) receives the most requests.
#
# - Since "channel" is a categorical variable, a bar chart is the most effective way to visualize frequency counts.
#
# - If one channel is overused or underutilized, it immediately stands out in the bar chart.

# %% [markdown]
# #####2. Insights found from this chart

# %% [markdown]
# 1. The highest bar represents the most frequently used customer support channel.
#
# 2. If Email is the most used, it suggests customers are comfortable with asynchronous support.
#
# 3. The shortest bar indicates underutilized channels.
#
# 4. If one channel dominates, it could lead to workload imbalance among support agents.

# %% [markdown]
# #####3. Insights that lead to Positive Growth

# %% [markdown]
# The insights gained from analyzing support request channels can have a significant positive impact on business operations, customer satisfaction, and overall efficiency.
#
# 1. Improving Customer Satisfaction
#
# 2. Enhancing Operational Efficiency
#
# 3. Optimizing Business Strategy

# %% [markdown]
# ####Chart - 2

# %%
import matplotlib.pyplot as plt

# Verify the correct column name for channel
print("Available Columns:", df.columns)

# Find the correct column containing "channel"
channel_col = [col for col in df.columns if "channel" in col.lower()]

if channel_col:
    correct_col = channel_col[0]  # Use the first matching column
    print(f"Using column: {correct_col}")

    # Convert to string and fill missing values with "Unknown"
    df[correct_col] = df[correct_col].astype(str).fillna("Unknown")

    # Count occurrences of each channel
    channel_counts = df[correct_col].value_counts()

    # Create Pie Chart
    plt.figure(figsize=(8, 8))
    plt.pie(channel_counts, labels=channel_counts.index, autopct='%1.1f%%', colors=plt.cm.Paired.colors)
    plt.title("Distribution of Customer Support Requests by Channel")
    plt.show()

else:
    print("Error: No column related to 'channel' found in the dataset.")
# Out:
# Available Columns: Index(['unique_id', 'channel_name', 'category', 'sub-category',
#        'customer_remarks', 'order_id', 'issue_reported_at', 'issue_responded',
#        'survey_response_date', 'agent_name', 'supervisor', 'manager',
#        'tenure_bucket', 'agent_shift', 'csat_score'],
#       dtype='object')
# Using column: channel_name

# %% [markdown]
# #####1. Reason to pick this specific chart

# %% [markdown]
# 1. Proportional Representation
#
# Clearly shows which channel is used the most and which is least preferred.
# Helps identify if one channel dominates or if the requests are evenly distributed.
#
# 2. Easy to Interpret
#
# Unlike bar charts, pie charts instantly convey the share of each category.
# Useful for non-technical audiences who need a quick visual summary.
#
# 3. Helps in Decision-Making

# %% [markdown]
# #####2. Insights found from the chart

# %% [markdown]
# - The largest slice of the pie represents the most commonly used support channel.
#
# - The smallest slice highlights an underutilized channel.
#
# - If the chart shows a balanced split between multiple channels, it means customers use multiple options.
#
# - If one channel dominates, it might lead to overburdened support staff and delays in responses.

# %% [markdown]
# #####3. Insights that lead to Positive Growth

# %% [markdown]
# 1. Enhancing Customer Satisfaction
#
# 2. Optimizing Resource Allocation
#
# 3.  Improving Business Strategy & Cost Efficiency
#
# 4. A faster, more efficient support system that boosts customer loyalty.

# %% [markdown]
# ####Chart - 3

# %%
import matplotlib.pyplot as plt

# Verify the correct date column in the dataset
print("Available Columns:", df.columns)

# Find a suitable date column dynamically
date_col = [col for col in df.columns if "date" in col.lower() or "time" in col.lower()]

if date_col:
    correct_col = date_col[0]  # Select the first matching date column
    print(f"Using column: {correct_col}")

    # Convert to datetime format
    df[correct_col] = pd.to_datetime(df[correct_col], errors='coerce')

    # Extract only valid dates
    df = df.dropna(subset=[correct_col])

    # Group data by date and count occurrences
    daily_counts = df.groupby(correct_col).size()

    # Create Line Chart
    plt.figure(figsize=(10, 5))
    plt.plot(daily_counts.index, daily_counts.values, marker='o', linestyle='-', color='b', label="Support Requests")
    plt.xlabel("Date")
    plt.ylabel("Number of Support Requests")
    plt.title("Customer Support Requests Over Time")
    plt.xticks(rotation=45)
    plt.legend()
    plt.grid(True)
    plt.show()

else:
    print("Error: No valid 'date' or 'time' column found in the dataset.")
# Out:
# Available Columns: Index(['unique_id', 'channel_name', 'category', 'sub-category',
#        'customer_remarks', 'order_id', 'issue_reported_at', 'issue_responded',
#        'survey_response_date', 'agent_name', 'supervisor', 'manager',
#        'tenure_bucket', 'agent_shift', 'csat_score'],
#       dtype='object')
# Using column: survey_response_date
# <ipython-input-65-9645a0821b7a>:14: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[correct_col] = pd.to_datetime(df[correct_col], errors='coerce')
# <ipython-input-65-9645a0821b7a>:20: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   daily_counts = df.groupby(correct_col).size()

# %% [markdown]
# #####1. Reason to pick this specific chart

# %% [markdown]
# A line chart is the best choice for this analysis because it effectively visualizes trends over time.
#
# - Shows Trends Over Time
# - Detects Patterns & Anomalies
# - Helps in Decision-Making
# - Easy to Interpret & Compare

# %% [markdown]
# #####2. Insights found from this chart

# %% [markdown]
# Insights from the Line Chart (Customer Support Requests Over Time)
#
# 1. Identifying Peak Support Demand
# 2. Seasonal Trends & Patterns
# 3. Operational Efficiency & Staffing Needs
# 4. Anomalies & Sudden Spikes
# 5. Evaluating Support Strategy

# %% [markdown]
# #####3. Insights that lead to Positive Growth

# %% [markdown]
# - Better Resource & Staffing Planning
# - Improving Customer Experience
# - Identifying Operational Bottlenecks
# - Business Growth & Strategic Decision

# %% [markdown]
# ####Chart - 4

# %%
#Scatter Plot
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure 'response_time_hours' is calculated
if 'response_time_hours' not in df.columns:
    df['issue_reported_at'] = pd.to_datetime(df['issue_reported_at'], errors='coerce')
    df['issue_responded'] = pd.to_datetime(df['issue_responded'], errors='coerce')
    df['response_time_hours'] = (df['issue_responded'] - df['issue_reported_at']).dt.total_seconds() / 3600

# Scatter plot
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='response_time_hours', y='csat_score', alpha=0.7, color="blue")

# Labels & Title
plt.xlabel("Response Time (Hours)", fontsize=12)
plt.ylabel("Customer Satisfaction Score (CSAT)", fontsize=12)
plt.title("Scatter Plot of Response Time vs. CSAT Score", fontsize=14)
plt.show()

# %% [markdown]
# #####1. Reason to pick this specific chart

# %% [markdown]
# 1. Shows Relationship, A scatter plot helps visualize the relationship between response time and customer satisfaction score (csat_score).
#
# 2. If the dots cluster in a certain direction, it suggests a positive or negative correlation between response time and CSAT.
#
# 3. Detects Outliers
#
# 4. Data Distribution

# %% [markdown]
# #####2. Insights found from this chart

# %% [markdown]
# - Possible Negative Correlation
# - Clusters of High CSAT
# - Outliers Detected
# - Data Speed & Variability
# - Optimization Opportunity

# %% [markdown]
# #####3. Insights that lead to Positive Growth

# %% [markdown]
# 1. Positive Impact
#   - Improved Customer Satisfaction
#   - Better Resource Allocation
#   - Enhanced Retention & Loyality
#   - Data-Driven SLA Optimization
#
# 2. Negative Impact
#   - Customer Churn & Lost Revenue
#   - Operational Inefficiencies
#   - Damaged Brand Reputation
#   - Missed Revenue Growth

# %% [markdown]
# ####Chart - 5

# %%
#Chart - 5 : Heatmap

# Compute the correlation matrix for numerical columns
corr_matrix = df.select_dtypes(include=['int64', 'float64']).corr()

# Plot heatmap
plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

# Titles and labels
plt.title("Correlation Heatmap of Numerical Features", fontsize=14)
plt.show()

# %% [markdown]
# #####1. Reason to pick this chart

# %% [markdown]
# - Heatmaps provide a clear, visual representation of correlations between numerical variables, helping identify trends and dependencies.
#
# -  By analyzing CSAT scores against factors like response time, agent shifts, and channels, businesses can pinpoint the biggest impact areas.
#
# - Unusual patterns or extreme values stand out clearly, allowing businesses to identify inefficiencies in their customer support process.

# %% [markdown]
# #####2. Insights found from this chart

# %% [markdown]
# - If response time increases and CSAT decreases, it shows longer wait times hurt customer satisfaction.
#
# - If CSAT score has a strong correlation with response time, tenure, or other factors, we can identify key improvement areas.
#
# - If CSAT scores remain low even for fast responses, it suggests that response quality is an issue, not just speed.
#
# - Optimize Response Time, Reduce delays in handling customer queries to boost CSAT.

# %% [markdown]
# #####3. Insights that lead to Positive and Negative Growth

# %% [markdown]
# 1. Positive Growth
#    - Faster Response Time
#    - Best Performing Agent Shifts Can set benchmark
#    - Strong Performance in live chat or phone support
#
# 2. Negative Growth
#    - Underperforming Support Channels
#    - Low CSAT scores in Specific agent shifts
#    - Unbalanced workload on agents

# %% [markdown]
# ####Chart - 6

# %%
#Chart - 6 : Pair Plot
# Select only numerical columns for the pair plot
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Check if we have numerical columns for plotting
if len(numerical_cols) > 1:
    plt.figure(figsize=(10, 8))
    sns.pairplot(df[numerical_cols], diag_kind='kde', corner=True)
    plt.suptitle("Pair Plot of Numerical Features", y=1.02)
    plt.show()
else:
    print("No numerical columns available for pair plot.")

# %% [markdown]
# #####1. Reason to pick this specific chart

# %% [markdown]
# - Visualizes Relationships between variables
# - Detects clusters & patterns
# - Easily spot outliers
# - Simple yet comprehensive

# %% [markdown]
# #####2. Insights that found from this chart

# %% [markdown]
# - Higher response time leads to Lower CSAT scores
# - Agent Tenure & Performance correlation
# - Clustering of hight & low satisfaction groups
# - Potential Outliers in service metrics
# - Identifying High-Performing Channels

# %% [markdown]
# #####3. Insights that lead to Positive and Negative Growth

# %% [markdown]
# 1. Positive Growth
#    - If the chart shows that lower response times correlate with higher CSAT scores, it proves that quick support leads to happier customers.
#
#    - If agents with longer tenure have higher CSAT scores, it suggests that experience improves service quality.
#
#    - The pair plot may show clusters of high and low CSAT scores, indicating different customer needs.
#
# 2. Negative Growth
#    - If high response times correlate with low CSAT scores, slow support is driving customer dissatisfaction.
#    - If some agents consistently have lower CSAT scores, they may need additional training.
#    - Extreme values in response time or CSAT scores might suggest system or operational issues.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### I Would like to suggest the Clients to achieve Business Objective

# %% [markdown]
# These are the few things,
# 1. Improve Response Time to Boost Customer Satisfaction
# 2. Optimize Customer Support Channels
# 3. Improve Agent Performance Through Training
# 4. Reduce Customer Churn Through Personalized Support
# 5. Use Data-Driven decision making

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The analysis of customer support interactions has provided valuable insights into the key factors influencing customer satisfaction, agent performance, and support channel effectiveness. By leveraging data-driven strategies, businesses can significantly improve their customer service operations and overall efficiency.
#
# Business Impacts & Future Recommendations
# - Implementing AI chatbots and automated ticketing can reduce response times.
# - Focusing on omnichannel support will improve customer accessibility and satisfaction.
# - Providing targeted training for agents will enhance performance and efficiency.
# - Personalized engagement strategies can reduce churn and improve loyalty.
# - Continuous data monitoring and predictive analytics will help in proactive decision-making.
